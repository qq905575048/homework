# %%
import numpy as np
from matplotlib import pyplot as plt

# 读取灰度图像
img = cv2.imread('MRI_BMP.bmp', 0)

# 检查图像是否读取成功
if img is None:
    print("Error: Image not found or unable to load.")
else:
    # 创建CLAHE对象
    
    
    
    # 应用CLAHE算法
   

    
    # 应用标准直方图均衡化
   

    
    # 保存处理后的图像
    
    
    
    # 计算直方图

    
    
    # 计算CDF
    
    
    
    # 归一化CDF
    
    
    
    # 使用Matplotlib显示图像、直方图和CDF
    
    
    
    # 显示原始图像
    
    
    
    # 显示CLAHE处理后的图像
    
    
    
    # 显示直方图均衡化后的图像
    
    
    
    # 显示原始直方图
    
    
    
    # 显示CLAHE直方图
    
    
    
    
    # 显示直方图均衡化后的直方图
    
    
    
    # 显示原始图像的CDF
    
    
    
    # 显示CLAHE处理后的CDF
   

    
    # 显示直方图均衡化后的CDF
